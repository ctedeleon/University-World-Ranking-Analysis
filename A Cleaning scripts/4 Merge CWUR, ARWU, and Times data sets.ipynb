# %% [markdown]
# # Import libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# # Import data sets

# %%
path = r'C:\Users\ctede\OneDrive\Desktop\World University Rankings Analysis'
ARWU = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'ARWU_tableau.csv'))
CWUR = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'CWUR_tableau.csv'))
Times = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Times_tableau.csv'))

# %%
#Check data frames 
ARWU.head()
# Out:
#    Unnamed: 0 world_rank     university_name national_rank  total_score  \
# 0           0          1  Harvard University             1        100.0
# 1           1          1  Harvard University             1        100.0
# 2           2          1  Harvard University             1        100.0
# 3           3          1  Harvard University             1        100.0
# 4           4          1  Harvard University             1        100.0
#
#    alumni  award   hici     ns    pub   pcp  year                   country  \
# 0   100.0  100.0  100.0  100.0  100.0  72.4  2005  United States of America
# 1   100.0  100.0  100.0  100.0  100.0  73.6  2006  United States of America
# 2   100.0  100.0  100.0  100.0  100.0  73.0  2007  United States of America
# 3   100.0  100.0  100.0  100.0  100.0  74.1  2008  United States of America
# 4   100.0  100.0  100.0  100.0  100.0  74.8  2009  United States of America
#
#   Score Category       region_2
# 0        Over 65  North America
# ...

# %%
CWUR.head()
# Out:
#    Unnamed: 0  world_rank                        university_name  \
# 0           0           1                     Harvard University
# 1           1           2  Massachusetts Institute of Technology
# 2           2           3                    Stanford University
# 3           3           4                University of Cambridge
# 4           4           5     California Institute of Technology
#
#                     country  national_rank  quality_of_education  \
# 0  United States of America              1                     7
# 1  United States of America              2                     9
# 2  United States of America              3                    17
# 3            United Kingdom              1                    10
# 4  United States of America              4                     2
#
#    alumni_employment  quality_of_faculty  publications  influence  citations  \
# 0                  9                   1             1          1          1
# ...

# %%
Times.head()
# Out:
#   world rank                        university name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching  international  research  citations  income  total score  \
# 0      99.7           72.0      98.7       98.8    34.0         96.0
# 1      97.7           54.0      98.0       99.9    83.0         96.0
# 2      97.8           82.0      91.4       99.9    87.0         95.0
# 3      98.3           29.0      98.1       99.2    64.0         94.0
# 4      90.9           70.0      95.4       99.9     NaN         94.0
#
#    num students  student staff ratio  international students  \
# ...

# %% [markdown]
# # Create subsets for each data frame

# %% [markdown]
# ### Times

# %%
times_cols = ["university name", "country", "research", "Median Score", "region", "teaching", "year", "international", "num students"]

# %%
times_sub = Times[times_cols]

# %%
times_sub.head()
# Out:
#                          university name                   country  research  \
# 0                     Harvard University  United States of America      98.7
# 1     California Institute of Technology  United States of America      98.0
# 2  Massachusetts Institute of Technology  United States of America      91.4
# 3                    Stanford University  United States of America      98.1
# 4                   Princeton University  United States of America      95.4
#
#    Median Score         region  teaching  year  international  num students
# 0         98.70  North America      99.7  2011           72.0       20152.0
# 1         97.70  North America      97.7  2011           54.0        2243.0
# 2         91.40  North America      97.8  2011           82.0       11074.0
# 3         98.10  North America      98.3  2011           29.0       15596.0
# 4         93.15  North America      90.9  2011           70.0        7929.0

# %%
#rename times columns so they are associated with the times dataframe
#housing_data.rename(columns={ 'households': 'houses' })
times_sub = times_sub.rename(columns={'Median Score':'times score', 'research':'times research','teaching':'times teaching','international':'times international','num students':'times num students'})

# %%
times_sub.head()
# Out:
#                          university name                   country  \
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America
#
#    times research  times score         region  times teaching  year  \
# 0            98.7        98.70  North America            99.7  2011
# 1            98.0        97.70  North America            97.7  2011
# 2            91.4        91.40  North America            97.8  2011
# 3            98.1        98.10  North America            98.3  2011
# 4            95.4        93.15  North America            90.9  2011
#
#    times international  times num students
# 0                 72.0             20152.0
# 1                 54.0              2243.0
# ...

# %%
#drop the total score from times sub dataframe (bc did not use this variable - too many nulls)
#times_sub = times_sub.drop(['total score'], axis=1)

# %%
#times_sub.head()

# %%
#times_sub = times_sub.rename(columns={'times_score':'times score'})

# %%
times_sub
# Out:
#                             university name                   country  \
# 0                        Harvard University  United States of America
# 1        California Institute of Technology  United States of America
# 2     Massachusetts Institute of Technology  United States of America
# 3                       Stanford University  United States of America
# 4                      Princeton University  United States of America
# ...                                     ...                       ...
# 2598                    Yeungnam University               South Korea
# 2599            Yıldız Technical University                    Turkey
# 2600               Yokohama City University                     Japan
# 2601           Yokohama National University                     Japan
# 2602                     Yuan Ze University                    Taiwan
#
#       times research  times score         region  times teaching  year  \
# ...

# %% [markdown]
# ### ARWU

# %%
#create a subset for ARWU
ARWU.head()
# Out:
#    Unnamed: 0 world_rank     university_name national_rank  total_score  \
# 0           0          1  Harvard University             1        100.0
# 1           1          1  Harvard University             1        100.0
# 2           2          1  Harvard University             1        100.0
# 3           3          1  Harvard University             1        100.0
# 4           4          1  Harvard University             1        100.0
#
#    alumni  award   hici     ns    pub   pcp  year                   country  \
# 0   100.0  100.0  100.0  100.0  100.0  72.4  2005  United States of America
# 1   100.0  100.0  100.0  100.0  100.0  73.6  2006  United States of America
# 2   100.0  100.0  100.0  100.0  100.0  73.0  2007  United States of America
# 3   100.0  100.0  100.0  100.0  100.0  74.1  2008  United States of America
# 4   100.0  100.0  100.0  100.0  100.0  74.8  2009  United States of America
#
#   Score Category       region_2
# 0        Over 65  North America
# ...

# %%
ARWU_cols = ["university_name", "region_2", "pcp", "country","award", "hici","pub","ns", "year", "alumni"]

# %%
arwu_sub = ARWU[ARWU_cols]

# %%
arwu_sub.head()
# Out:
#       university_name       region_2   pcp                   country  award  \
# 0  Harvard University  North America  72.4  United States of America  100.0
# 1  Harvard University  North America  73.6  United States of America  100.0
# 2  Harvard University  North America  73.0  United States of America  100.0
# 3  Harvard University  North America  74.1  United States of America  100.0
# 4  Harvard University  North America  74.8  United States of America  100.0
#
#     hici    pub     ns  year  alumni
# 0  100.0  100.0  100.0  2005   100.0
# 1  100.0  100.0  100.0  2006   100.0
# 2  100.0  100.0  100.0  2007   100.0
# 3  100.0  100.0  100.0  2008   100.0
# 4  100.0  100.0  100.0  2009   100.0

# %%
#rename columns 
arwu_sub = arwu_sub.rename(columns={'university_name':'university name','region_2':'region','pcp':'ARWU score','award':'ARWU award', 'hici':'ARWU hici','pub':'ARWU pub','ns':'ARWU ns','alumni':'ARWU alumni'})

# %%
arwu_sub.head()
# Out:
#       university name         region  ARWU score                   country  \
# 0  Harvard University  North America        72.4  United States of America
# 1  Harvard University  North America        73.6  United States of America
# 2  Harvard University  North America        73.0  United States of America
# 3  Harvard University  North America        74.1  United States of America
# 4  Harvard University  North America        74.8  United States of America
#
#    ARWU award  ARWU hici  ARWU pub  ARWU ns  year  ARWU alumni
# 0       100.0      100.0     100.0    100.0  2005        100.0
# 1       100.0      100.0     100.0    100.0  2006        100.0
# 2       100.0      100.0     100.0    100.0  2007        100.0
# 3       100.0      100.0     100.0    100.0  2008        100.0
# 4       100.0      100.0     100.0    100.0  2009        100.0

# %%
#CWUR data frame 
CWUR.head()
# Out:
#    Unnamed: 0  world_rank                        university_name  \
# 0           0           1                     Harvard University
# 1           1           2  Massachusetts Institute of Technology
# 2           2           3                    Stanford University
# 3           3           4                University of Cambridge
# 4           4           5     California Institute of Technology
#
#                     country  national_rank  quality_of_education  \
# 0  United States of America              1                     7
# 1  United States of America              2                     9
# 2  United States of America              3                    17
# 3            United Kingdom              1                    10
# 4  United States of America              4                     2
#
#    alumni_employment  quality_of_faculty  publications  influence  citations  \
# 0                  9                   1             1          1          1
# ...

# %%
#sub dataframe 
CWUR_cols = ["university_name", "country", "region_2","score", "quality_of_faculty", "publications", "year","alumni_employment", "quality_of_education","influence", "citations", "patents"]

# %%
cwur_sub = CWUR[CWUR_cols]

# %%
cwur_sub.head()
# Out:
#                          university_name                   country  \
# 0                     Harvard University  United States of America
# 1  Massachusetts Institute of Technology  United States of America
# 2                    Stanford University  United States of America
# 3                University of Cambridge            United Kingdom
# 4     California Institute of Technology  United States of America
#
#         region_2   score  quality_of_faculty  publications  year  \
# 0  North America  100.00                   1             1  2012
# 1  North America   91.67                   3            12  2012
# 2  North America   89.50                   5             4  2012
# 3         Europe   86.17                   4            16  2012
# 4  North America   85.21                   7            37  2012
#
#    alumni_employment  quality_of_education  influence  citations  patents
# 0                  9                     7          1          1        5
# ...

# %%
#rename columns 
cwur_sub = cwur_sub.rename(columns={'university_name':'university name','region_2':'region','quality_of_faculty':'CWUR faculty','publications':'CWUR pub','alumni_employment': 'CWUR alumni','quality_of_education': 'CWUR edu','influence':'CWUR influence','citations':'CWUR citations','patents':'CWUR patents','score':'CWUR score'})

# %%
cwur_sub
# Out:
#                             university name                   country  \
# 0                        Harvard University  United States of America
# 1     Massachusetts Institute of Technology  United States of America
# 2                       Stanford University  United States of America
# 3                   University of Cambridge            United Kingdom
# 4        California Institute of Technology  United States of America
# ...                                     ...                       ...
# 2195              University of the Algarve                  Portugal
# 2196                  Alexandria University                     Egypt
# 2197            Federal University of Ceará                    Brazil
# 2198                 University of A Coruña                     Spain
# 2199        China Pharmaceutical University                     China
#
#              region  CWUR score  CWUR faculty  CWUR pub  year  CWUR alumni  \
# ...

# %% [markdown]
# # Merge sub dataframes

# %%
times_sub.head()
# Out:
#                          university name                   country  \
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America
#
#    times research  times score         region  times teaching  year  \
# 0            98.7        98.70  North America            99.7  2011
# 1            98.0        97.70  North America            97.7  2011
# 2            91.4        91.40  North America            97.8  2011
# 3            98.1        98.10  North America            98.3  2011
# 4            95.4        93.15  North America            90.9  2011
#
#    times international  times num students
# 0                 72.0             20152.0
# 1                 54.0              2243.0
# ...

# %%
arwu_sub.head()
# Out:
#       university name         region  ARWU score                   country  \
# 0  Harvard University  North America        72.4  United States of America
# 1  Harvard University  North America        73.6  United States of America
# 2  Harvard University  North America        73.0  United States of America
# 3  Harvard University  North America        74.1  United States of America
# 4  Harvard University  North America        74.8  United States of America
#
#    ARWU award  ARWU hici  ARWU pub  ARWU ns  year  ARWU alumni
# 0       100.0      100.0     100.0    100.0  2005        100.0
# 1       100.0      100.0     100.0    100.0  2006        100.0
# 2       100.0      100.0     100.0    100.0  2007        100.0
# 3       100.0      100.0     100.0    100.0  2008        100.0
# 4       100.0      100.0     100.0    100.0  2009        100.0

# %%
#Test the merge without overwriting 
pd.merge(times_sub, arwu_sub, on = ['university name','country','region','year'],how='outer')
# Out:
#                             university name                   country  \
# 0                        Harvard University  United States of America
# 1        California Institute of Technology  United States of America
# 2     Massachusetts Institute of Technology  United States of America
# 3                       Stanford University  United States of America
# 4                      Princeton University  United States of America
# ...                                     ...                       ...
# 4783       University of the Basque Country                     Spain
# 4784       University of the Basque Country                     Spain
# 4785             Capital Medical University                     China
# 4786                    University of Genoa                     Italy
# 4787                  University of Seville                     Spain
#
#       times research  times score         region  times teaching  year  \
# ...

# %% [markdown]
# #### The "outer" merge was used so that all data was included from both subset dataframes.

# %%
#Create the fully combined/merged dataframe: df_ords_prods_merged
#ARWU_merged = ARWU.merge(school_country, on = 'university_name')
times_arwu_merged = times_sub.merge(arwu_sub, on =['university name', 'country','region','year'],how='outer')

# %%
times_arwu_merged.head()
# Out:
#                          university name                   country  \
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America
#
#    times research  times score         region  times teaching  year  \
# 0            98.7        98.70  North America            99.7  2011
# 1            98.0        97.70  North America            97.7  2011
# 2            91.4        91.40  North America            97.8  2011
# 3            98.1        98.10  North America            98.3  2011
# 4            95.4        93.15  North America            90.9  2011
#
#    times international  times num students  ARWU score  ARWU award  ARWU hici  \
# ...

# %%
#test the merge for the cwur data frame 
pd.merge(times_arwu_merged, cwur_sub, on =['university name', 'country', 'year'],how='outer')
# Out:
#                             university name                   country  \
# 0                        Harvard University  United States of America
# 1        California Institute of Technology  United States of America
# 2     Massachusetts Institute of Technology  United States of America
# 3                       Stanford University  United States of America
# 4                      Princeton University  United States of America
# ...                                     ...                       ...
# 6040              University of the Algarve                  Portugal
# 6041                  Alexandria University                     Egypt
# 6042            Federal University of Ceará                    Brazil
# 6043                 University of A Coruña                     Spain
# 6044        China Pharmaceutical University                     China
#
#       times research  times score       region_x  times teaching  year  \
# ...

# %%
#merge cwur 
df_merged = times_arwu_merged.merge(cwur_sub, on =['university name', 'country','region','year'], how='outer')

# %%
df_merged.head()
# Out:
#                          university name                   country  \
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America
#
#    times research  times score         region  times teaching  year  \
# 0            98.7        98.70  North America            99.7  2011
# 1            98.0        97.70  North America            97.7  2011
# 2            91.4        91.40  North America            97.8  2011
# 3            98.1        98.10  North America            98.3  2011
# 4            95.4        93.15  North America            90.9  2011
#
#    times international  times num students  ARWU score  ...  ARWU ns  \
# 0                 72.0             20152.0        70.5  ...    100.0
# ...

# %%
#rename score to CWUR score 
#df_merged = df_merged.rename(columns={'score':'CWUR score'})

# %%
df_merged.head()
# Out:
#                          university name                   country  \
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America
#
#    times research  times score         region  times teaching  year  \
# 0            98.7        98.70  North America            99.7  2011
# 1            98.0        97.70  North America            97.7  2011
# 2            91.4        91.40  North America            97.8  2011
# 3            98.1        98.10  North America            98.3  2011
# 4            95.4        93.15  North America            90.9  2011
#
#    times international  times num students  ARWU score  ...  ARWU ns  \
# 0                 72.0             20152.0        70.5  ...    100.0
# ...

# %%
df_merged.shape
# Out:
# (6045, 23)

# %% [markdown]
# # Export new merged dataframe for tableau

# %%
#Export
df_merged.to_csv(os.path.join(path,'02 Data', 'Prepared Data', 'merged_datasets_outer_.csv'))
#this file was renamed "merged_datasets_outer_2.csv" in the file explorer window bc it was mistyped in this script

# %% [markdown]
# # Create a new merged data set using a left merge

# %%
#Test the merge without overwriting 
pd.merge(times_sub, arwu_sub, on = ['university name','country','year'], how ='left')
# Out:
#                             university name                   country  \
# 0                        Harvard University  United States of America
# 1        California Institute of Technology  United States of America
# 2     Massachusetts Institute of Technology  United States of America
# 3                       Stanford University  United States of America
# 4                      Princeton University  United States of America
# ...                                     ...                       ...
# 2598                    Yeungnam University               South Korea
# 2599            Yıldız Technical University                    Turkey
# 2600               Yokohama City University                     Japan
# 2601           Yokohama National University                     Japan
# 2602                     Yuan Ze University                    Taiwan
#
#       times research  times score         region  times teaching  year  \
# ...

# %%
times_arwu_merged_2 = times_sub.merge(arwu_sub, on =['university name', 'country','year'], how='left')

# %%
times_arwu_merged_2.shape
# Out:
# (2603, 12)

# %%
#test the merge for the cwur data frame 
pd.merge(times_arwu_merged_2, cwur_sub, on =['university name', 'country', 'year'], how='left')
# Out:
#                             university name                   country  \
# 0                        Harvard University  United States of America
# 1        California Institute of Technology  United States of America
# 2     Massachusetts Institute of Technology  United States of America
# 3                       Stanford University  United States of America
# 4                      Princeton University  United States of America
# ...                                     ...                       ...
# 2598                    Yeungnam University               South Korea
# 2599            Yıldız Technical University                    Turkey
# 2600               Yokohama City University                     Japan
# 2601           Yokohama National University                     Japan
# 2602                     Yuan Ze University                    Taiwan
#
#       times research  times score         region  times teaching  year  \
# ...

# %%
merged_2 = times_arwu_merged_2.merge(cwur_sub, on =['university name', 'country','year'], how='left')

# %%
merged_2.shape
# Out:
# (2603, 15)

# %%
merged_2.head()
# Out:
#                          university name                   country  \
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America
#
#    times research  times score         region  times teaching  year  \
# 0            98.7        98.70  North America            99.7  2011
# 1            98.0        97.70  North America            97.7  2011
# 2            91.4        91.40  North America            97.8  2011
# 3            98.1        98.10  North America            98.3  2011
# 4            95.4        93.15  North America            90.9  2011
#
#    ARWU score  ARWU award  ARWU hici  ARWU pub  ARWU ns  score  CWUR faculty  \
# ...

# %%
merged_2[merged_2['university name']=='Harvard University']
# Out:
#          university name                   country  times research  \
# 0     Harvard University  United States of America            98.7
# 201   Harvard University  United States of America            97.4
# 605   Harvard University  United States of America            98.6
# 1003  Harvard University  United States of America            98.5
# 1403  Harvard University  United States of America            98.6
# 1808  Harvard University  United States of America            99.0
#
#       times score         region  times teaching  year  ARWU score  \
# 0            98.7  North America            99.7  2011        70.5
# 201          95.8  North America            95.8  2012        71.1
# 605          94.9  North America            94.9  2013        72.5
# 1003         95.3  North America            95.3  2014        75.3
# 1403         92.9  North America            92.9  2015        76.6
# 1808         83.6  North America            83.6  2016         NaN
#
# ...

# %%
#rename columns 
merged_2 = merged_2.rename(columns={'score':'CWUR score'})

# %%
merged_2.head()
# Out:
#                          university name                   country  \
# 0                     Harvard University  United States of America
# 1     California Institute of Technology  United States of America
# 2  Massachusetts Institute of Technology  United States of America
# 3                    Stanford University  United States of America
# 4                   Princeton University  United States of America
#
#    times research  times score         region  times teaching  year  \
# 0            98.7        98.70  North America            99.7  2011
# 1            98.0        97.70  North America            97.7  2011
# 2            91.4        91.40  North America            97.8  2011
# 3            98.1        98.10  North America            98.3  2011
# 4            95.4        93.15  North America            90.9  2011
#
#    ARWU score  ARWU award  ARWU hici  ARWU pub  ARWU ns  CWUR score  \
# 0        70.5       100.0      100.0     100.0    100.0         NaN
# ...

# %% [markdown]
# # Export new left merge dataframe

# %%
#Export
merged_2.to_csv(os.path.join(path,'02 Data', 'Prepared Data', 'merged_datasets_final.csv'))
