# %% [markdown]
# # Import new, clean data sets

# %%
#Import libraries
import pandas as pd
import numpy as np
import os 

#Import clean data sets 
path = r'C:\Users\ctede\OneDrive\Desktop\World University Rankings Analysis'
CWUR = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'CWUR_clean.pkl'))
AWUR = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'AwUR_clean.pkl'))
Times = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Times_clean.pkl'))

# %% [markdown]
# # Finish cleaning Times data

# %%
#Check summary stats
Times.describe()
# Out:
#           teaching  international     research    citations      income  \
# count  2603.000000    2594.000000  2603.000000  2603.000000  2385.00000
# mean     37.801498      51.554356    35.910257    60.921629    48.54130
# std      17.604218      22.113535    21.254805    23.073219    21.19839
# min       9.900000       7.000000     2.900000     1.200000    24.00000
# 25%      24.700000      33.000000    19.600000    45.500000    33.00000
# 50%      33.900000      50.000000    30.500000    62.500000    41.00000
# 75%      46.400000      69.000000    47.250000    79.050000    59.00000
# max      99.700000     100.000000    99.400000   100.000000   100.00000
#
#        total_score   num_students  student_staff_ratio  \
# count  1201.000000    2544.000000          2544.000000
# mean     59.406328   23873.758648            18.445283
# std      12.804482   17675.946877            11.458698
# min      41.000000     462.000000             0.600000
# ...

# %%
Times.head(20)
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# ...

# %% [markdown]
# # Missing data cont.

# %%
#Check for missing data values in num_students variable
Times[Times['num_students'].isnull()==True]
# Out:
#      world_rank                                    university_name  \
# 45           43                            University of Wisconsin
# 81           81                                 University of York
# 85           86   London School of Economics and Political Science
# 111         112                                 Bilkent University
# 115         115                     University of Hawai’i at Mānoa
# 157         158                 Georgia Health Sciences University
# 246          47   London School of Economics and Political Science
# 321         121                                 University of York
# 361         162               Medical University of South Carolina
# 396         197                 Georgia Health Sciences University
# 401     201-225                                 Bilkent University
# 419     201-225  University of Medicine and Dentistry of New Je...
# 443     226-250                              University of Hamburg
# ...

# %%
#Check for missing data values in female_male_ratio variable
Times[Times['female_male_ratio'].isnull()==True]
# Out:
#      world_rank                             university_name  \
# 0             1                          Harvard University
# 16           17                       University of Toronto
# 17           18                         Columbia University
# 25           26                         University of Tokyo
# 36           37                           Peking University
# ...         ...                                         ...
# 2509    601-800  Moscow Institute of Physics and Technology
# 2514    601-800             National Chung Cheng University
# 2534    601-800                          University of Pécs
# 2555    601-800                          Shinshu University
# 2600    601-800                    Yokohama City University
#
#                        country  teaching  international  research  citations  \
# 0     United States of America      99.7             72      98.7       98.8
# 16                      Canada      75.8           <NA>      87.9       82.2
# ...

# %% [markdown]
# # Check for full duplicate data

# %%
#Create a dataframe that has full duplicates
Times_dups = Times[Times.duplicated()]
Times_dups
# Out:
# Empty DataFrame
# Columns: [world_rank, university_name, country, teaching, international, research, citations, income, total_score, num_students, student_staff_ratio, international_students, female_male_ratio, year]
# Index: []

# %% [markdown]
# #### There are no full duplicates in the Times data set

# %% [markdown]
# # Check for other consistencies
# ### Mispellings

# %%
Times['country'].value_counts()
# Out:
# United States of America     659
# United Kingdom               300
# Germany                      152
# Australia                    117
# Canada                       108
#                             ...
# Unted Kingdom                  1
# Cyprus                         1
# Unisted States of America      1
# Luxembourg                     1
# Lithuania                      1
# Name: country, Length: 72, dtype: int64

# %%
#Create a new dataframe that fixes the mispellings
#Times['country'].replace(to_replace= 'Unted Kingdom', value = 'United Kingdom')
# Out:
# 0       United States of America
# 1       United States of America
# 2       United States of America
# 3       United States of America
# 4       United States of America
#                   ...
# 2598                 South Korea
# 2599                      Turkey
# 2600                       Japan
# 2601                       Japan
# 2602                      Taiwan
# Name: country, Length: 2603, dtype: object

# %%
Times['country'].value_counts()
# Out:
# United States of America     659
# United Kingdom               300
# Germany                      152
# Australia                    117
# Canada                       108
#                             ...
# Unted Kingdom                  1
# Cyprus                         1
# Unisted States of America      1
# Luxembourg                     1
# Lithuania                      1
# Name: country, Length: 72, dtype: int64

# %%
Times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching  international  research  citations  income  total_score  \
# 0      99.7             72      98.7       98.8      34           96
# 1      97.7             54      98.0       99.9      83           96
# 2      97.8             82      91.4       99.9      87           95
# 3      98.3             29      98.1       99.2      64           94
# 4      90.9             70      95.4       99.9    <NA>           94
#
#    num_students  student_staff_ratio  international_students  \
# ...

# %%
# Applying the condition to change misspelled countries
#df['gender'].mask(df['gender'] == 'female', 0, inplace=True)
Times['country'].mask(Times['country'] == 'Unisted States of America', 'United States of America', inplace=True)

# %%
#Check to see if spelling corrected 
Times['country'].value_counts()
# Out:
# United States of America    660
# United Kingdom              300
# Germany                     152
# Australia                   117
# Canada                      108
#                            ...
# Serbia                        1
# Belarus                       1
# Cyprus                        1
# Unted Kingdom                 1
# Lithuania                     1
# Name: country, Length: 71, dtype: int64

# %%
#Use same code to change "Unted Kingdom" spelling
Times['country'].mask(Times['country']=='Unted Kingdom', 'United Kingdom', inplace=True)

# %%
#Checkc to see if spellilng corrected 
Times['country'].value_counts()
# Out:
# United States of America    660
# United Kingdom              301
# Germany                     152
# Australia                   117
# Canada                      108
#                            ...
# Luxembourg                    1
# Serbia                        1
# Belarus                       1
# Cyprus                        1
# Lithuania                     1
# Name: country, Length: 70, dtype: int64

# %%
#Change United States of America to United States -- to stay consistent with other world ranking data sets
Times['country'].mask(Times['country'] == 'United States of America', 'United States', inplace=True)

# %%
#Check counts of school/university names 
Times['university_name'].value_counts()
# Out:
# Harvard University                               6
# Lancaster University                             6
# University of Alberta                            6
# University of Glasgow                            6
# Stockholm University                             6
#                                                 ..
# Indian Institute of Technology Guwahati          1
# Huazhong University of Science and Technology    1
# University of Haifa                              1
# University of Granada                            1
# Yokohama National University                     1
# Name: university_name, Length: 818, dtype: int64

# %%
Times.head()
# Out:
#   world_rank                        university_name        country  teaching  \
# 0          1                     Harvard University  United States      99.7
# 1          2     California Institute of Technology  United States      97.7
# 2          3  Massachusetts Institute of Technology  United States      97.8
# 3          4                    Stanford University  United States      98.3
# 4          5                   Princeton University  United States      90.9
#
#    international  research  citations  income  total_score  num_students  \
# 0             72      98.7       98.8      34           96         20152
# 1             54      98.0       99.9      83           96          2243
# 2             82      91.4       99.9      87           95         11074
# 3             29      98.1       99.2      64           94         15596
# 4             70      95.4       99.9    <NA>           94          7929
#
# ...

# %% [markdown]
# # Export clean Times data frame

# %%
#Clean Times data frame 
Times.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Times_clean.pkl'))

# %% [markdown]
# # Check CWUR and AWUR clean dataframes

# %%
CWUR.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University   United States
# 1           2  Massachusetts Institute of Technology   United States
# 2           3                    Stanford University   United States
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology   United States
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  patents   score  year
# ...

# %%
AWUR.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
#Change variable/column name from CWUR 
#"institution" to "university_name"
#rankings_pd.rename(columns = {'test':'TEST'}, inplace = True)
CWUR.rename(columns = {'institution':'university_name'}, inplace=True)

# %%
CWUR.head()
# Out:
#    world_rank                        university_name         country  \
# 0           1                     Harvard University   United States
# 1           2  Massachusetts Institute of Technology   United States
# 2           3                    Stanford University   United States
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology   United States
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  patents   score  year
# ...

# %%
#Check clean CWUR dataset summary stats
CWUR.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
# check number of rows/columns 
CWUR
# Out:
#       world_rank                        university_name         country  \
# 0              1                     Harvard University   United States
# 1              2  Massachusetts Institute of Technology   United States
# 2              3                    Stanford University   United States
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology   United States
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
#Check descriptive stats of AWUR (clean data)
AWUR.describe()
# Out:
#        total_score       alumni       award         hici           ns  \
# count  1101.000000  4896.000000  4895.00000  4895.000000  4875.000000
# mean     36.383470     9.161724     7.69191    16.221491    16.078503
# std      13.557186    14.140636    15.49411    14.382710    12.511529
# min      23.500000     0.000000     0.00000     0.000000     0.000000
# 25%      27.400000     0.000000     0.00000     7.300000     8.000000
# 50%      31.300000     0.000000     0.00000    12.600000    12.800000
# 75%      41.800000    15.600000    13.40000    21.700000    19.800000
# max     100.000000   100.000000   100.00000   100.000000   100.000000
#
#                pub          pcp         year
# count  4895.000000  4895.000000  4896.000000
# mean     38.254648    21.242329  2009.657884
# std      13.050809     9.254351     3.197546
# min       7.300000     8.300000  2005.000000
# 25%      28.900000    15.600000  2007.000000
# 50%      36.000000    19.000000  2009.000000
# ...

# %% [markdown]
# # Export CWUR data frame

# %%
#Clean CWUR data frame 
CWUR.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'CWUR_clean.pkl'))
