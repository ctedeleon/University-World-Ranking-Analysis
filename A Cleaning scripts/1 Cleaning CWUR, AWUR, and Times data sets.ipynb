# %% [markdown]
# # Cleaning World Ranking Data Sets

# %% [markdown]
# ### Import data set(s) and libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os 

#Import CWUR data set 
path = r'C:\Users\ctede\OneDrive\Desktop\World University Rankings Analysis'
CWUR = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'cwurData.csv'), index_col = False)
AWUR = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'shanghaiData.csv'), index_col = False)
Times = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'timesData.csv'), index_col = False)

# %% [markdown]
# ## CWUR data set
# ### Show Summary Stats

# %%
#Show descriptive/summary statistics
CWUR.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# min              1.000000      1.000000     1.000000     1.000000
# 25%            175.750000    175.750000   175.750000   161.000000
# 50%            210.000000    450.500000   450.500000   406.000000
# 75%            218.000000    725.000000   725.250000   645.000000
# max            218.000000   1000.000000   991.000000   812.000000
#
#        broad_impact      patents        score         year
# count   2000.000000  2200.000000  2200.000000  2200.000000
# mean     496.699500   433.346364    47.798395  2014.318182
# std      286.919755   273.996525     7.760806     0.762130
# min        1.000000     1.000000    43.360000  2012.000000
# 25%      250.500000   170.750000    44.460000  2014.000000
# 50%      496.000000   426.000000    45.100000  2014.000000
# 75%      741.000000   714.250000    47.545000  2015.000000
# max     1000.000000   871.000000   100.000000  2015.000000

# %%
CWUR #number of rows/columns
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# 2                 3                    17                 11
# 3                 1                    10                 24
# 4                 4                     2                 29
# ...             ...                   ...                ...
# 2195              7                   367                567
# 2196              4                   236                566
# 2197             18                   367                549
# 2198             40                   367                567
# 2199             83                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                      1             1          1          1           NaN
# 1                      3            12          4          4           NaN
# 2                      5             4          2          2           NaN
# 3                      4            16         16         11           NaN
# 4                      7            37         22         22           NaN
# ...                  ...           ...        ...        ...           ...
# 2195                 218           926        845        812         969.0
# 2196                 218           997        908        645         981.0
# 2197                 218           830        823        812         975.0
# 2198                 218           886        974        812         975.0
# 2199                 218           861        991        812         981.0
#
#       patents   score  year
# 0           5  100.00  2012
# 1           1   91.67  2012
# 2          15   89.50  2012
# 3          50   86.17  2012
# 4          18   85.21  2012
# ...       ...     ...   ...
# 2195      816   44.03  2015
# 2196      871   44.03  2015
# 2197      824   44.03  2015
# 2198      651   44.02  2015
# 2199      547   44.02  2015
#
# [2200 rows x 14 columns]

# %% [markdown]
# ### Check data types

# %%
#Check data types 
for col in CWUR.columns.tolist():
    weird = (CWUR[[col]].applymap(type) != CWUR[[col]].iloc[0].apply(type)).any(axis=1)
    if len (CWUR[weird]) > 0: 
        print(col)

# %%
#No columns printed in above output --> there are no columns with a mixed data type

# %% [markdown]
# ### Check for missing data

# %%
#Find and add all null/missing values by column
CWUR.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
#Show missing values in a dataframe 
CWUR_nulls = CWUR[CWUR['broad_impact'].isnull()==True]

# %%
CWUR_nulls
# Out:
#      world_rank                            institution         country  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5     California Institute of Technology             USA
# ..          ...                                    ...             ...
# 195          96         Australian National University       Australia
# 196          97                  University of Alberta          Canada
# 197          98                 University of Helsinki         Finland
# 198          99     Paris Diderot University - Paris 7          France
# 199         100        Georgia Institute of Technology             USA
#
#      national_rank  quality_of_education  alumni_employment  \
# 0                1                     7                  9
# 1                2                     9                 17
# 2                3                    17                 11
# 3                1                    10                 24
# 4                4                     2                 29
# ..             ...                   ...                ...
# 195              2                   101                101
# 196              4                   101                101
# 197              1                    69                101
# 198              5                    28                101
# 199             57                   101                 85
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                     1             1          1          1           NaN
# 1                     3            12          4          4           NaN
# 2                     5             4          2          2           NaN
# 3                     4            16         16         11           NaN
# 4                     7            37         22         22           NaN
# ..                  ...           ...        ...        ...           ...
# 195                  43           101        101        101           NaN
# 196                 101            68        101         92           NaN
# 197                  81            74         79         71           NaN
# 198                  72           101         87        101           NaN
# 199                 101            97        101         43           NaN
#
#      patents   score  year
# 0          5  100.00  2012
# 1          1   91.67  2012
# 2         15   89.50  2012
# 3         50   86.17  2012
# 4         18   85.21  2012
# ..       ...     ...   ...
# 195      101   44.50  2013
# 196       81   44.50  2013
# 197      101   44.39  2013
# 198      101   44.36  2013
# 199       32   44.26  2013
#
# [200 rows x 14 columns]

# %%
#Create a new dataframe that excludes the broad impact column ("broad impact" has a lot of missing values and meaning
#of variable is unknown)
#df = df.drop('column_name', axis=1)
CWUR_drop = CWUR.drop('broad_impact', axis=1)

# %%
CWUR_drop.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  patents   score  year
# 0             1          1          1        5  100.00  2012
# 1            12          4          4        1   91.67  2012
# 2             4          2          2       15   89.50  2012
# 3            16         16         11       50   86.17  2012
# 4            37         22         22       18   85.21  2012

# %% [markdown]
# ### Finding full duplicate data

# %%
#Create a dataframe that has full duplicates
CWUR_dups = CWUR[CWUR.duplicated()]
CWUR_dups
# Out:
# Empty DataFrame
# Columns: [world_rank, institution, country, national_rank, quality_of_education, alumni_employment, quality_of_faculty, publications, influence, citations, broad_impact, patents, score, year]
# Index: []

# %% [markdown]
# #### There are no full duplicates in the CWUR dataframe

# %% [markdown]
# ### Check consistency of values in 'country' variable

# %%
CWUR_drop['country'].head()
# Out:
# 0               USA
# 1               USA
# 2               USA
# 3    United Kingdom
# 4               USA
# Name: country, dtype: object

# %%
#Use same code to change "USA" to United States
#Times['country'].mask(Times['country']=='Unted Kingdom', 'United Kingdom', inplace=True)
CWUR_drop['country'].mask(CWUR_drop['country']=='USA', 'United States', inplace=True)

# %%
CWUR_drop['country'].value_counts()
# Out:
# United States           573
# China                   167
# Japan                   159
# United Kingdom          144
# Germany                 115
# France                  109
# Italy                    96
# Spain                    81
# Canada                   72
# South Korea              72
# Australia                58
# Taiwan                   46
# Brazil                   36
# India                    31
# Netherlands              29
# Switzerland              26
# Sweden                   24
# Austria                  24
# Israel                   22
# Finland                  20
# Turkey                   20
# Belgium                  20
# Poland                   18
# Iran                     16
# Ireland                  16
# Portugal                 14
# Greece                   14
# Hong Kong                12
# Norway                   12
# New Zealand              12
# Hungary                  12
# Denmark                  12
# South Africa             10
# Czech Republic           10
# Russia                    9
# Saudi Arabia              8
# Egypt                     8
# Chile                     8
# Argentina                 7
# Thailand                  6
# Malaysia                  6
# Singapore                 5
# Colombia                  4
# Mexico                    4
# Slovenia                  4
# Romania                   3
# Lebanon                   2
# Croatia                   2
# Estonia                   2
# Slovak Republic           2
# Iceland                   2
# Serbia                    2
# Bulgaria                  2
# Lithuania                 2
# Uganda                    2
# United Arab Emirates      2
# Uruguay                   2
# Cyprus                    2
# Puerto Rico               2
# Name: country, dtype: int64

# %% [markdown]
# ## AWUR data set
# ### Show summary stats

# %%
AWUR.describe()
# Out:
#        total_score       alumni       award         hici           ns  \
# count  1101.000000  4896.000000  4895.00000  4895.000000  4875.000000
# mean     36.383470     9.161724     7.69191    16.221491    16.078503
# std      13.557186    14.140636    15.49411    14.382710    12.511529
# min      23.500000     0.000000     0.00000     0.000000     0.000000
# 25%      27.400000     0.000000     0.00000     7.300000     8.000000
# 50%      31.300000     0.000000     0.00000    12.600000    12.800000
# 75%      41.800000    15.600000    13.40000    21.700000    19.800000
# max     100.000000   100.000000   100.00000   100.000000   100.000000
#
#                pub          pcp         year
# count  4895.000000  4895.000000  4897.000000
# mean     38.254648    21.242329  2009.658566
# std      13.050809     9.254351     3.197576
# min       7.300000     8.300000  2005.000000
# 25%      28.900000    15.600000  2007.000000
# 50%      36.000000    19.000000  2009.000000
# 75%      45.300000    24.500000  2012.000000
# max     100.000000   100.000000  2015.000000

# %%
AWUR.head(20)
# Out:
#    world_rank                              university_name national_rank  \
# 0           1                           Harvard University             1
# 1           2                      University of Cambridge             1
# 2           3                          Stanford University             2
# 3           4           University of California, Berkeley             3
# 4           5  Massachusetts Institute of Technology (MIT)             4
# 5           6           California Institute of Technology             5
# 6           7                          Columbia University             6
# 7           8                         Princeton University             7
# 8           9                        University of Chicago             8
# 9          10                         University of Oxford             2
# 10         11                              Yale University             9
# 11         12                           Cornell University            10
# 12         13          University of California, San Diego            11
# 13         14        University of California, Los Angeles            12
# 14         15                   University of Pennsylvania            13
# 15         16            University of Wisconsin - Madison            14
# 16         17                     University of Washington            15
# 17         18      University of California, San Francisco            16
# 18         19                 The Johns Hopkins University            17
# 19         20                      The University of Tokyo             1
#
#     total_score  alumni  award   hici     ns    pub    pcp  year
# 0         100.0   100.0  100.0  100.0  100.0  100.0   72.4  2005
# 1          73.6    99.8   93.4   53.3   56.6   70.9   66.9  2005
# 2          73.4    41.1   72.2   88.5   70.9   72.3   65.0  2005
# 3          72.8    71.8   76.0   69.4   73.9   72.2   52.7  2005
# 4          70.1    74.0   80.6   66.7   65.8   64.3   53.0  2005
# 5          67.1    59.2   68.6   59.8   65.8   52.5  100.0  2005
# 6          62.3    79.4   60.6   56.1   54.2   69.5   45.4  2005
# 7          60.9    63.4   76.8   60.9   48.7   48.5   59.1  2005
# 8          60.1    75.6   81.9   50.3   44.7   56.4   42.2  2005
# 9          59.7    64.3   59.1   48.4   55.6   68.4   53.2  2005
# 10         56.9    52.1   44.5   60.3   57.2   63.9   49.3  2005
# 11         54.6    46.5   52.4   55.0   48.8   66.3   39.8  2005
# 12         51.0    17.7   34.7   59.8   56.5   64.5   46.6  2005
# 13         50.6    27.3   32.8   56.7   50.1   75.6   34.3  2005
# 14         50.2    35.5   35.1   56.7   42.9   71.8   39.1  2005
# 15         49.2    43.0   36.3   52.1   46.3   68.7   29.0  2005
# 16         48.4    28.8   32.4   53.9   47.1   73.8   27.2  2005
# 17         47.8     0.0   37.6   55.6   57.9   58.8   45.2  2005
# 18         46.9    51.4   28.3   41.6   52.2   67.7   24.9  2005
# 19         46.7    36.0   14.4   38.5   52.1   86.5   34.7  2005

# %%
AWUR #number of rows/columns
# Out:
#      world_rank                              university_name national_rank  \
# 0             1                           Harvard University             1
# 1             2                      University of Cambridge             1
# 2             3                          Stanford University             2
# 3             4           University of California, Berkeley             3
# 4             5  Massachusetts Institute of Technology (MIT)             4
# ...         ...                                          ...           ...
# 4892    401-500                        University of Trieste         11-20
# 4893    401-500                       University of Zaragoza          9-13
# 4894    401-500                        Utah State University       126-146
# 4895    401-500              Vienna University of Technology           4-6
# 4896    401-500                       Wake Forest University       126-146
#
#       total_score  alumni  award   hici     ns    pub   pcp  year
# 0           100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1            73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2            73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3            72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4            70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005
# ...           ...     ...    ...    ...    ...    ...   ...   ...
# 4892          NaN     0.0    0.0    5.0   10.9   25.1  20.1  2015
# 4893          NaN     0.0    0.0    7.6    5.1   33.3  13.1  2015
# 4894          NaN    13.6    0.0    3.6   10.8   25.1  15.5  2015
# 4895          NaN     0.0    0.0    0.0   12.2   28.8  22.9  2015
# 4896          NaN     0.0    0.0   14.9    7.5   25.0  11.9  2015
#
# [4897 rows x 11 columns]

# %% [markdown]
# ### Check data types

# %%
#Check for mixed data types 
for col in AWUR.columns.tolist():
    weird = (AWUR[[col]].applymap(type) != AWUR[[col]].iloc[0].apply(type)).any(axis=1)
    if len (AWUR[weird]) > 0: 
        print(col)
# Out:
# university_name
# national_rank

# %%
#Change data type for university name to string
AWUR['university_name'] = AWUR['university_name'].astype('str')

# %%
#Change data type for national rank to string
AWUR['national_rank'] = AWUR['national_rank'].astype('str')

# %%
#Check data types (again)
for col in AWUR.columns.tolist():
    weird = (AWUR[[col]].applymap(type) != AWUR[[col]].iloc[0].apply(type)).any(axis=1)
    if len (AWUR[weird]) > 0: 
        print(col)

# %% [markdown]
# ### Check for missing data

# %%
AWUR.isnull().sum()
# Out:
# world_rank            0
# university_name       0
# national_rank         0
# total_score        3796
# alumni                1
# award                 2
# hici                  2
# ns                   22
# pub                   2
# pcp                   2
# year                  0
# dtype: int64

# %%
#Show missing values in a dataframe 
AWUR[AWUR['ns'].isnull()==True]
# Out:
#      world_rank                                   university_name  \
# 217     203-300  London School of Economics and Political Science
# 348     301-400                     Stockholm School of Economics
# 718     201-300  London School of Economics and Political Science
# 847     301-400                     Stockholm School of Economics
# 1158    151-202  London School of Economics and Political Science
# 1347    305-402                     Stockholm School of Economics
# 1726    201-302  London School of Economics and Political Science
# 1963    402-503                     Stockholm School of Economics
# 2226    201-302  London School of Economics and Political Science
# 2466    402-501                     Stockholm School of Economics
# 2730    201-300  London School of Economics and Political Science
# 2859    301-400                     Stockholm School of Economics
# 3122    102-150  London School of Economics and Political Science
# 3364    301-400                     Stockholm School of Economics
# 3464    401-500                                Tilburg University
# 3797    201-300                              University of Oregon
# 3896         99                                               nan
# 4006    101-150  London School of Economics and Political Science
# 4340    401-500                     Stockholm School of Economics
# 4347    401-500                                Tilburg University
# 4505    101-150  London School of Economics and Political Science
# 4843    401-500                     Stockholm School of Economics
#
#      national_rank  total_score  alumni  award  hici  ns   pub   pcp  year
# 217          20-30          NaN    19.8    0.0  15.7 NaN  26.1  16.2  2005
# 348          10-11          NaN     0.0   17.1   0.0 NaN  11.0  29.4  2005
# 718          23-33          NaN    19.1    0.0  15.4 NaN  25.8  28.6  2006
# 847          10-11          NaN     0.0   16.7   0.0 NaN  10.8  29.4  2006
# 1158         16-23          NaN    18.6    0.0  16.6 NaN  25.3  28.4  2007
# 1347            10          NaN     0.0   16.7   0.0 NaN  10.4  28.8  2007
# 1726         23-33          NaN    17.7    0.0  16.3 NaN  26.4  17.2  2008
# 1963         10-11          NaN     0.0   16.7   0.0 NaN  10.3  29.2  2008
# 2226         24-33          NaN    17.3    0.0  14.5 NaN  26.1  28.5  2009
# 2466         10-11          NaN     0.0   16.7   0.0 NaN  10.7  29.8  2009
# 2730         20-30          NaN    16.9    0.0  16.1 NaN  26.0  24.8  2010
# 2859            10          NaN     0.0   16.6   0.0 NaN  10.7  39.0  2010
# 3122         11-15          NaN    22.8   16.2  16.1 NaN  28.0  25.9  2011
# 3364          9-10          NaN     0.0   16.6   0.0 NaN  10.4  37.0  2011
# 3464            13          NaN     0.0    0.0   0.0 NaN  27.0  18.9  2011
# 3797        86-109          NaN     9.0    NaN   NaN NaN   NaN   NaN  2012
# 3896           nan          NaN     NaN    NaN   NaN NaN   NaN   NaN  2013
# 4006          9-17          NaN    20.4   16.3  15.2 NaN  30.5  28.0  2014
# 4340            11          NaN     0.0   16.3   0.0 NaN   9.4  37.9  2014
# 4347            13          NaN     0.0    0.0   0.0 NaN  28.1  21.2  2014
# 4505         10-17          NaN    19.9   16.3  15.2 NaN  31.2  28.7  2015
# 4843            11          NaN     0.0   16.3   0.0 NaN  10.2  39.4  2015

# %%
#Drop index 3896 (world rank 99) bc missing all data values 
AWUR_drop = AWUR.drop(3896)

# %%
AWUR_drop[AWUR_drop['world_rank']==99]
# Out:
# Empty DataFrame
# Columns: [world_rank, university_name, national_rank, total_score, alumni, award, hici, ns, pub, pcp, year]
# Index: []

# %%
#Show "London School of Economics and Political Science" school name 
AWUR_drop[AWUR_drop['university_name']=='London School of Economics and Political Science']
# Out:
#      world_rank                                   university_name  \
# 217     203-300  London School of Economics and Political Science
# 718     201-300  London School of Economics and Political Science
# 1158    151-202  London School of Economics and Political Science
# 1726    201-302  London School of Economics and Political Science
# 2226    201-302  London School of Economics and Political Science
# 2730    201-300  London School of Economics and Political Science
# 3122    102-150  London School of Economics and Political Science
# 3622    101-150  London School of Economics and Political Science
# 4006    101-150  London School of Economics and Political Science
# 4505    101-150  London School of Economics and Political Science
#
#      national_rank  total_score  alumni  award  hici   ns   pub   pcp  year
# 217          20-30          NaN    19.8    0.0  15.7  NaN  26.1  16.2  2005
# 718          23-33          NaN    19.1    0.0  15.4  NaN  25.8  28.6  2006
# 1158         16-23          NaN    18.6    0.0  16.6  NaN  25.3  28.4  2007
# 1726         23-33          NaN    17.7    0.0  16.3  NaN  26.4  17.2  2008
# 2226         24-33          NaN    17.3    0.0  14.5  NaN  26.1  28.5  2009
# 2730         20-30          NaN    16.9    0.0  16.1  NaN  26.0  24.8  2010
# 3122         11-15          NaN    22.8   16.2  16.1  NaN  28.0  25.9  2011
# 3622         10-14          NaN    21.0   16.8  16.2  0.0  28.5  26.0  2012
# 4006          9-17          NaN    20.4   16.3  15.2  NaN  30.5  28.0  2014
# 4505         10-17          NaN    19.9   16.3  15.2  NaN  31.2  28.7  2015

# %%
#Show "Stockholm School of Economics" school name 
AWUR_drop[AWUR_drop['university_name']=='Stockholm School of Economics']
# Out:
#      world_rank                university_name national_rank  total_score  \
# 348     301-400  Stockholm School of Economics         10-11          NaN
# 847     301-400  Stockholm School of Economics         10-11          NaN
# 1347    305-402  Stockholm School of Economics            10          NaN
# 1963    402-503  Stockholm School of Economics         10-11          NaN
# 2466    402-501  Stockholm School of Economics         10-11          NaN
# 2859    301-400  Stockholm School of Economics            10          NaN
# 3364    301-400  Stockholm School of Economics          9-10          NaN
# 4340    401-500  Stockholm School of Economics            11          NaN
# 4843    401-500  Stockholm School of Economics            11          NaN
#
#       alumni  award  hici  ns   pub   pcp  year
# 348      0.0   17.1   0.0 NaN  11.0  29.4  2005
# 847      0.0   16.7   0.0 NaN  10.8  29.4  2006
# 1347     0.0   16.7   0.0 NaN  10.4  28.8  2007
# 1963     0.0   16.7   0.0 NaN  10.3  29.2  2008
# 2466     0.0   16.7   0.0 NaN  10.7  29.8  2009
# 2859     0.0   16.6   0.0 NaN  10.7  39.0  2010
# 3364     0.0   16.6   0.0 NaN  10.4  37.0  2011
# 4340     0.0   16.3   0.0 NaN   9.4  37.9  2014
# 4843     0.0   16.3   0.0 NaN  10.2  39.4  2015

# %% [markdown]
# ### Finding full duplicate data

# %%
#Create a dataframe that has full duplicates
AWUR_dups = AWUR_drop[AWUR_drop.duplicated()]
AWUR_dups
# Out:
# Empty DataFrame
# Columns: [world_rank, university_name, national_rank, total_score, alumni, award, hici, ns, pub, pcp, year]
# Index: []

# %% [markdown]
# #### There were no full duplicate in the AWUR dataframe

# %% [markdown]
# ### Check consistency/value counts for "year"

# %%
AWUR_drop['year'].value_counts()
# Out:
# 2007    510
# 2008    503
# 2009    501
# 2005    500
# 2006    500
# 2010    500
# 2011    500
# 2014    500
# 2015    500
# 2012    284
# 2013     98
# Name: year, dtype: int64

# %%
#Check 2007 year 
AWUR_drop[AWUR_drop['year']==2007].head(20)
# Out:
#      world_rank                              university_name national_rank  \
# 1000          1                           Harvard University             1
# 1001          2                          Stanford University             2
# 1002          3           University of California, Berkeley             3
# 1003          4                      University of Cambridge             1
# 1004          5  Massachusetts Institute of Technology (MIT)             4
# 1005          6           California Institute of Technology             5
# 1006          7                          Columbia University             6
# 1007          8                         Princeton University             7
# 1008          9                        University of Chicago             8
# 1009         10                         University of Oxford             2
# 1010         11                              Yale University             9
# 1011         12                           Cornell University            10
# 1012         13        University of California, Los Angeles            11
# 1013         14          University of California, San Diego            12
# 1014         15                   University of Pennsylvania            13
# 1015         16                     University of Washington            14
# 1016         17            University of Wisconsin - Madison            15
# 1017         18      University of California, San Francisco            16
# 1018         19                 The Johns Hopkins University            17
# 1019         20                      The University of Tokyo             1
#
# 1498          NaN     0.0    0.0   7.4   1.6  27.5  20.6  2007
# 1499          NaN     0.0    0.0   7.4   7.0  23.3  20.2  2007
# 1500          NaN     0.0    0.0  10.5   7.3  21.8  11.4  2007
# 1501          NaN    13.2    0.0   0.0   5.4  24.8  11.4  2007
# 1502          NaN     0.0    0.0   0.0   8.7  23.8  17.6  2007
# 1503          NaN     0.0    0.0   7.4  10.3  22.9  13.9  2007
# 1504          NaN     0.0    0.0   7.4   4.3  28.1  13.3  2007
# 1505          NaN     0.0    0.0   7.4   9.2  22.3  11.4  2007
# 1506          NaN    14.4    0.0   0.0   9.4  21.4  15.7  2007
# 1507          NaN     0.0    0.0   0.0  13.9  26.2  13.3  2007
# 1508          NaN     0.0    0.0   0.0   7.5  28.4  13.7  2007
# 1509          NaN     0.0    0.0   0.0   7.8  27.4  12.8  2007

# %%
#Check 2013 year 
AWUR_drop[AWUR_drop['year']==2013].head(20)
# Out:
#      world_rank                               university_name national_rank  \
# 3798          1                            Harvard University           1.0
# 3799          2                           Stanford University           2.0
# 3800          3            University of California, Berkeley           3.0
# 3801          4   Massachusetts Institute of Technology (MIT)           4.0
# 3802          5                       University of Cambridge           1.0
# 3803          6            California Institute of Technology           5.0
# 3804          7                          Princeton University           6.0
# 3805          8                           Columbia University           7.0
# 3806          9                         University of Chicago           8.0
# 3807         10                          University of Oxford           2.0
# 3808         11                               Yale University           9.0
# 3809         12         University of California, Los Angeles          10.0
# 3810         13                            Cornell University          11.0
# 3811         14           University of California, San Diego          12.0
# 3812         15                    University of Pennsylvania          13.0
# 3813         16                      University of Washington          14.0
# 3814         17                  The Johns Hopkins University          15.0
# 3815         18       University of California, San Francisco          16.0
# 3816         19             University of Wisconsin - Madison          17.0
# 3817         20  Swiss Federal Institute of Technology Zurich           1.0
#
#       total_score  alumni  award   hici     ns    pub    pcp  year
# 3798        100.0   100.0  100.0  100.0  100.0  100.0   72.5  2013
# 3799         72.6    40.0   80.7   88.9   68.7   69.4   50.4  2013
# 3800         71.3    67.8   79.0   69.7   68.5   68.1   54.7  2013
# 3801         71.1    68.0   81.3   68.2   69.7   60.1   65.0  2013
# 3802         69.6    79.1   97.3   54.6   54.0   66.2   53.3  2013
# 3803         62.9    47.8   67.2   57.4   62.0   45.2  100.0  2013
# 3804         61.9    52.9   89.2   62.2   45.8   44.0   66.9  2013
# 3805         59.8    66.1   66.4   57.4   49.8   68.0   31.9  2013
# 3806         57.1    60.9   83.4   52.2   41.9   49.8   39.5  2013
# 3807         55.9    51.8   55.3   48.9   51.3   69.9   41.2  2013
# 3808         55.4    47.5   44.5   59.7   60.7   62.4   36.3  2013
# 3809         52.9    27.3   47.4   57.7   51.7   71.2   31.1  2013
# 3810         50.0    38.2   50.2   54.9   45.0   55.2   37.6  2013
# 3811         49.9    20.0   35.8   60.3   55.5   63.4   35.5  2013
# 3812         49.6    33.0   34.1   57.9   47.4   66.7   37.7  2013
# 3813         48.3    22.0   31.8   55.1   52.3   70.8   27.9  2013
# 3814         46.9    39.3   33.9   42.2   49.7   68.8   27.4  2013
#      world_rank     university_name national_rank  total_score  alumni  award  \
# 164     153-202  Queen's University           6-8          NaN     0.0    0.0
# 660     151-200  Queen's University           6-8          NaN     0.0    0.0
# 1233    203-304  Queen's University          8-17          NaN     0.0    0.0
# 1234    203-304  Queen's University         24-33          NaN    22.0    0.0
# 1739    201-302  Queen's University          7-18          NaN     0.0    0.0
# 1740    201-302  Queen's University         23-33          NaN    20.9    0.0
# 2240    201-302  Queen's University          7-18          NaN     0.0    0.0
# 2741    201-300  Queen's University          9-18          NaN     0.0    0.0
# 2742    201-300  Queen's University         20-30          NaN    19.9    0.0
# 3240    201-300  Queen's University          9-18          NaN     0.0    0.0
# 3742    201-300  Queen's University          8-17          NaN     0.0    0.0
# 4131    201-300  Queen's University          8-16          NaN     0.0    0.0
# 4636    201-300  Queen's University          7-16          NaN     0.0    0.0
#
#       hici    ns   pub   pcp  year
# 164   19.2  17.0  35.2  18.5  2005
# 660   18.8  16.5  36.6  20.2  2006
# 1233  16.6  17.1  35.4  19.2  2007
# 1234   0.0  12.8  31.0  21.3  2007
# 1739  16.3  14.8  35.6  27.0  2008
# 1740   0.0  14.4  33.2  25.4  2008
# 2240  16.2  15.2  35.8  20.2  2009
# 2741  16.1  15.3  36.8  20.3  2010
# 2742   0.0  14.8  33.3  16.2  2010
# 3240  16.1  14.1  35.4  19.2  2011
# 3742  16.2  13.7  33.9  18.7  2012
# 4131  13.1  11.8  33.9  19.2  2014
# 4636  13.1  11.9  32.6  19.0  2015

# %% [markdown]
# #### Universities will appear wice in a single year (i.e. Queen's University in 2007, 2008, 2010) if the world rank and national rank are different. In 2010, the hici, ns, pub, and pcp numbers differed, causing the national rank to be different. I would have to contact the data source to determine which year was correct / which year to keep.

# %% [markdown]
# # Export CWUR and AWUR data frames

# %%
#Clean CWUR data frame 
CWUR_drop.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'CWUR_clean.pkl'))

# %%
#Clean AWUR data frame 
AWUR_drop.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'AwUR_clean.pkl'))

# %% [markdown]
# ## Times data set

# %% [markdown]
# ### Show summary statistics

# %%
#Show descriptive/summary statistics
Times.describe()
# Out:
#           teaching     research    citations  student_staff_ratio         year
# count  2603.000000  2603.000000  2603.000000          2544.000000  2603.000000
# mean     37.801498    35.910257    60.921629            18.445283  2014.075682
# std      17.604218    21.254805    23.073219            11.458698     1.685733
# min       9.900000     2.900000     1.200000             0.600000  2011.000000
# 25%      24.700000    19.600000    45.500000            11.975000  2013.000000
# 50%      33.900000    30.500000    62.500000            16.100000  2014.000000
# 75%      46.400000    47.250000    79.050000            21.500000  2016.000000
# max      99.700000    99.400000   100.000000           162.600000  2016.000000

# %%
#Show all columns 
Times
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# 2     United States of America      97.8          82.3      91.4       99.9
# 3     United States of America      98.3          29.5      98.1       99.2
# 4     United States of America      90.9          70.3      95.4       99.9
# ...                        ...       ...           ...       ...        ...
# 2598               South Korea      18.6          24.3      10.9       26.5
# 2599                    Turkey      14.5          14.9       7.6       19.3
# 2600                     Japan      24.0          16.1      10.2       36.4
# 2601                     Japan      20.1          23.3      16.0       13.5
# 2602                    Taiwan      16.2          17.7      18.3       28.6
#
#      income total_score num_students  student_staff_ratio  \
# 0      34.5        96.1       20,152                  8.9
# 1      83.7        96.0        2,243                  6.9
# 2      87.5        95.6       11,074                  9.0
# 3      64.3        94.3       15,596                  7.8
# 4         -        94.2        7,929                  8.4
# ...     ...         ...          ...                  ...
# 2598   35.4           -       21,958                 15.3
# 2599   44.0           -       31,268                 28.7
# 2600   37.9           -        4,122                  3.7
# 2601   40.4           -       10,117                 12.1
# 2602   39.8           -        8,663                 20.6
#
#      international_students female_male_ratio  year
# 0                       25%               NaN  2011
# 1                       27%           33 : 67  2011
# 2                       33%           37 : 63  2011
# 3                       22%           42 : 58  2011
# 4                       27%           45 : 55  2011
# ...                     ...               ...   ...
# 2598                     3%           48 : 52  2016
# 2599                     2%           36 : 64  2016
# 2600                     3%               NaN  2016
# 2601                     8%           28 : 72  2016
# 2602                     4%           43 : 57  2016
#
# [2603 rows x 14 columns]

# %% [markdown]
# ### Check data types

# %%
#Check for mixed data types 
for col in Times.columns.tolist():
    weird = (Times[[col]].applymap(type) != Times[[col]].iloc[0].apply(type)).any(axis=1)
    if len (Times[weird]) > 0: 
        print(col)
# Out:
# num_students
# international_students
# female_male_ratio

# %%
#Check data type for num_students 
Times['num_students'].dtype
# Out:
# dtype('O')

# %%
#"num_students" has commas in the data values -- remove commas 
Times['num_students']=Times['num_students'].str.replace(',','')

# %%
#Check num_students 
Times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# 0        20152                  8.9                    25%               NaN
# 1         2243                  6.9                    27%           33 : 67
# 2        11074                  9.0                    33%           37 : 63
# 3        15596                  7.8                    22%           42 : 58
# 4         7929                  8.4                    27%           45 : 55
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
#Change data type of num_students from string to integer 
Times['num_students'] = Times['num_students'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10964\2916377981.py in <module>
#       1 #Change data type of num_students from string to integer
# ----> 2 Times['num_students'] = Times['num_students'].astype('int')
#
# C:\apps\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\apps\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# C:\apps\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# C:\apps\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# C:\apps\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# C:\apps\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# C:\apps\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1152         # work around NumPy brokenness, #1987
#    1153         if np.issubdtype(dtype.type, np.integer):
# -> 1154             return lib.astype_intsafe(arr, dtype)
#    1155
#    1156         # if we have a datetime/timedelta array of objects
#
# C:\apps\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: cannot convert float NaN to integer

# %%
#Replace "NaN" with "0" so can convert data type to integer 
#missing values for num_students is 59 out of 2603 = less than 5% of data)
#imes['num_students']=Times['num_students'].str.replace(',','')

# %% [markdown]
# ### Check for missing data

# %%
#Check for missing data 
Times.isnull().sum()
# Out:
# world_rank                  0
# university_name             0
# country                     0
# teaching                    0
# international               0
# research                    0
# citations                   0
# income                      0
# total_score                 0
# num_students               59
# student_staff_ratio        59
# international_students     67
# female_male_ratio         233
# year                        0
# dtype: int64

# %%
Times[Times['num_students'].isnull()==True]
# Out:
#      world_rank                                    university_name  \
# 45           43                            University of Wisconsin
# 81           81                                 University of York
# 85           86   London School of Economics and Political Science
# 111         112                                 Bilkent University
# 115         115                     University of Hawai’i at Mānoa
# 157         158                 Georgia Health Sciences University
# 246          47   London School of Economics and Political Science
# 321         121                                 University of York
# 361         162               Medical University of South Carolina
# 396         197                 Georgia Health Sciences University
# 401     201-225                                 Bilkent University
# 419     201-225  University of Medicine and Dentistry of New Je...
# 443     226-250                              University of Hamburg
# 466     251-275                     University of Hawai’i at Mānoa
# 494     276-300                               University of Kansas
# 495     276-300                             University of Kentucky
# 536     301-350                             University of Oklahoma
# 551     350-400                                   Aston University
# 571     350-400                  Michigan Technological University
# 578     350-400                            Old Dominion University
# 597     350-400                              University of Wyoming
# 640          39   London School of Economics and Political Science
# 704         103                                 University of York
# 790         189               Medical University of South Carolina
# 827     226-250                                 Bilkent University
# 831     226-250                 Georgia Health Sciences University
# 895     276-300                               University of Kansas
# 934     301-350                             University of Kentucky
# 944     301-350                              University of Vermont
# 974     351-400                      Southern Methodist University
# 986     351-400                             University of Oklahoma
# 1000    351-400                              University of Wyoming
# 1033         32   London School of Economics and Political Science
# 1102        100                                 University of York
# 1229    226-250                                 Bilkent University
# 1230    226-250                 Georgia Health Sciences University
# 1293    276-300                               University of Kansas
# 1348    301-350                              University of Vermont
# 1373    351-400                            Old Dominion University
# 1391    351-400                             University of Oklahoma
# 1401    351-400                              University of Wyoming
# 1435         34   London School of Economics and Political Science
# 1516        113                                 University of York
# 1603    201-225                                 Bilkent University
# 1639    226-250                     Technical University of Berlin
# 1663    251-275                     University of Hawai’i at Mānoa
# 1666    251-275                           University of New Mexico
# 1713    301-350                   Illinois Institute of Technology
# 1736    301-350                               University of Kansas
# 1741    301-350                             University of Oklahoma
# 1755    351-400                                   Aston University
# 1795    351-400                              University of Vermont
# 466                     NaN               NaN  2012
# 494                     NaN               NaN  2012
# 495                     NaN               NaN  2012
# 536                     NaN               NaN  2012
# 551                     NaN               NaN  2012
# 571                     NaN               NaN  2012
# 578                     NaN               NaN  2012
# 597                     NaN               NaN  2012
# 640                     NaN               NaN  2013
# 704                     NaN               NaN  2013
# 790                     NaN               NaN  2013
# 827                     NaN               NaN  2013
# 831                     NaN               NaN  2013
# 895                     NaN               NaN  2013
# 934                     NaN               NaN  2013
# 944                     NaN               NaN  2013
# 974                     NaN               NaN  2013
# 986                     NaN               NaN  2013
# 1000                    NaN               NaN  2013
# 1033                    NaN               NaN  2014
# 1102                    NaN               NaN  2014
# 1229                    NaN               NaN  2014
# 1230                    NaN               NaN  2014
# 1293                    NaN               NaN  2014
# 1348                    NaN               NaN  2014
# 1373                    NaN               NaN  2014
# 1391                    NaN               NaN  2014
# 1401                    NaN               NaN  2014
# 1435                    NaN               NaN  2015
# 1516                    NaN               NaN  2015
# 1603                    NaN               NaN  2015
# 1639                    NaN               NaN  2015
# 1663                    NaN               NaN  2015
# 1666                    NaN               NaN  2015
# 1713                    NaN               NaN  2015
# 1736                    NaN               NaN  2015
# 1741                    NaN               NaN  2015
# 1755                    NaN               NaN  2015
# 1795                    NaN               NaN  2015
# 1825                    NaN               NaN  2016
# 1935                    NaN               NaN  2016
# 2019                    NaN               NaN  2016
# 2153                    NaN               NaN  2016
# 2177                    NaN               NaN  2016
# 2205                    NaN               NaN  2016
# 2421                    NaN               NaN  2016

# %%
#Change data type of num_students from string to integer 
Times['num_students'] = Times['num_students'].astype('float').astype('Int64')

# %%
Times.head(50)
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# 13         14                                 Cornell University
# 14         15  ETH Zurich – Swiss Federal Institute of Techno...
# 15         15                             University of Michigan
# 16         17                              University of Toronto
# 17         18                                Columbia University
# 18         19                         University of Pennsylvania
# 19         20                         Carnegie Mellon University
# 20         21                            University of Hong Kong
# 21         22                          University College London
# 22         23                           University of Washington
# 23         24                                    Duke University
# 24         25                            Northwestern University
# 25         26                                University of Tokyo
# 26         27                    Georgia Institute of Technology
# 27         28        Pohang University of Science and Technology
# 28         29            University of California, Santa Barbara
# 29         30                     University of British Columbia
# 30         30        University of North Carolina at Chapel Hill
# 31         32                University of California, San Diego
# 32         33         University of Illinois at Urbana-Champaign
# 33         34                   National University of Singapore
# 34         35                                  McGill University
# 35         36                            University of Melbourne
# 36         37                                  Peking University
# 37         38                  Washington University in St Louis
# 38         39                                École Polytechnique
# 39         40                            University of Edinburgh
# 40         41     Hong Kong University of Science and Technology
# 41         42                           École Normale Supérieure
# 42         43                     Australian National University
# 43         43                               Karolinska Institute
# 8    92.9        90.6         15060                 11.7
# 9       -        89.5         11751                  4.4
# 10      -        87.7         38206                 10.3
# 11      -        86.9         14221                  6.9
# 12  100.0        86.4         15128                  3.6
# 13   34.7        83.9         21424                 10.2
# 14      -        83.4         18178                 14.7
# 15   59.6        83.4         41786                  9.0
# 16      -        82.0         66198                 19.5
# 17      -        81.0         25055                  5.9
# 18   43.7        79.5         20376                  6.5
# 19   53.7        79.3         11885                 13.1
# 20   56.5        79.2         19835                 17.6
# 21   39.0        78.4         26607                 10.7
# 22   32.8        78.0         44020                 11.8
# 23  100.0        76.5         15172                  4.8
# 24      -        75.9         18334                 13.8
# 25      -        75.6         26199                  5.7
# 26   95.1        75.3         19967                 20.1
# 27  100.0        75.1          3055                 10.1
# 28   89.8        75.0         22020                 27.3
# 29   42.6        73.8         50152                 17.6
# 30   50.2        73.8         26518                  7.3
# 31   51.8        73.2         27233                  6.5
# 32      -        73.0         42727                 18.7
# 33   40.5        72.9         31592                 15.5
# 34      -        71.7         31326                 13.7
# 35   47.7        71.0         40128                 23.7
# 36   98.6        70.7         40148                  8.3
# 37      -        69.9         12528                  5.7
# 38      -        69.5          2429                  4.8
# 39   42.2        69.2         25774                 14.1
# 40   64.1        69.0         11385                 23.8
# 41   30.7        68.6          2400                  7.9
# 42      -        67.0         14604                 19.2
# 43   73.3        67.0          7774                 11.5
# 44   31.7        67.0         25581                 25.6
# 45      -        67.0          <NA>                  NaN
# 46   29.2        66.9          6333                  9.0
# 47   38.0        66.5          9666                 10.5
# 48      -        66.0         26614                 16.1
# 49   30.3        66.0         14290                  7.9
#
#    international_students female_male_ratio  year
# 0                     25%               NaN  2011
# 1                     27%           33 : 67  2011
# 2                     33%           37 : 63  2011
# 3                     22%           42 : 58  2011
# 4                     27%           45 : 55  2011
# 5                     34%           46 : 54  2011
# 6                     34%           46 : 54  2011
# 7                     15%           50 : 50  2011
# 8                     51%           37 : 63  2011
# 9                     20%           50 : 50  2011
# 10                    15%           52 : 48  2011
# 11                    21%           42 : 58  2011
# 12                    23%           50 : 50  2011
# 13                    19%           48 : 52  2011
# 14                    37%           31 : 69  2011
# 15                    16%           48 : 52  2011
# 16                    15%               NaN  2011
# 17                    28%               NaN  2011
# 18                    20%           51 : 49  2011
# 19                    35%           39 : 61  2011
# 20                    38%           53 : 47  2011
# 21                    46%           56 : 44  2011
# 22                    13%           53 : 47  2011
# 23                    17%           49 : 51  2011
# 24                    15%           48 : 52  2011
# 25                    10%               NaN  2011
# 26                    26%           31 : 69  2011
# 27                     4%           20 : 80  2011
# 28                    11%           52 : 48  2011
# 29                    25%           54 : 46  2011
# 30                     8%           58 : 42  2011
# 31                    11%           48 : 52  2011
# 32                    20%           47 : 53  2011
# 33                    34%           49 : 51  2011
# 34                    23%           56 : 44  2011
# 35                    35%           55 : 45  2011
# 36                    14%               NaN  2011
# 37                    17%               NaN  2011
# 38                    30%           18 : 82  2011
# 39                    36%           58 : 42  2011
# 40                    36%               NaN  2011
# 41                    20%           46 : 54  2011
# 42                    35%           52 : 48  2011
# 43                    22%           70 : 30  2011
# 44                    12%           51 : 49  2011
# 45                    NaN               NaN  2011
# 46                    26%           44 : 56  2011
# 47                    54%           27 : 73  2011
# 48                    16%           52 : 48  2011
# 49                     2%               NaN  2011

# %%
#Show descriptive/summary statistics -- to see if num_students is included
Times.describe()
# Out:
#           teaching     research    citations   num_students  \
# count  2603.000000  2603.000000  2603.000000    2544.000000
# mean     37.801498    35.910257    60.921629   23873.758648
# std      17.604218    21.254805    23.073219   17675.946877
# min       9.900000     2.900000     1.200000     462.000000
# 25%      24.700000    19.600000    45.500000   12637.750000
# 50%      33.900000    30.500000    62.500000   20851.000000
# 75%      46.400000    47.250000    79.050000   29991.000000
# max      99.700000    99.400000   100.000000  379231.000000
#
#        student_staff_ratio         year
# count          2544.000000  2603.000000
# mean             18.445283  2014.075682
# std              11.458698     1.685733
# min               0.600000  2011.000000
# 25%              11.975000  2013.000000
# 50%              16.100000  2014.000000
# 75%              21.500000  2016.000000
# max             162.600000  2016.000000

# %%
#Check data type of income variable 
Times['income'].dtype
# Out:
# dtype('O')

# %%
#Change data type of income from string to integer 
Times['income'] = Times['income'].astype('float').astype('Int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10964\3915805157.py in <module>
#       1 #Change data type of income from string to integer
# ----> 2 Times['income'] = Times['income'].astype('float').astype('Int64')
#
# C:\apps\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\apps\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# C:\apps\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# C:\apps\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# C:\apps\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# C:\apps\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# C:\apps\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1179     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1180         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1181         return arr.astype(dtype, copy=True)
#    1182
#    1183     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
#Replace the "-" with "0" 
Times['income']=Times['income'].str.replace('-','NaN')

# %%
Times.head(20)
# Out:
#    world_rank                                    university_name  \
# 0           1                                 Harvard University
# 1           2                 California Institute of Technology
# 2           3              Massachusetts Institute of Technology
# 3           4                                Stanford University
# 4           5                               Princeton University
# 5           6                            University of Cambridge
# 6           6                               University of Oxford
# 7           8                 University of California, Berkeley
# 8           9                            Imperial College London
# 9          10                                    Yale University
# 10         11              University of California, Los Angeles
# 11         12                              University of Chicago
# 12         13                           Johns Hopkins University
# 13         14                                 Cornell University
# 14         15  ETH Zurich – Swiss Federal Institute of Techno...
# 15         15                             University of Michigan
# 16         17                              University of Toronto
# 17         18                                Columbia University
# 18         19                         University of Pennsylvania
# 19         20                         Carnegie Mellon University
#
#                      country  teaching international  research  citations  \
# 0   United States of America      99.7          72.4      98.7       98.8
# 1   United States of America      97.7          54.6      98.0       99.9
# 2   United States of America      97.8          82.3      91.4       99.9
# 3   United States of America      98.3          29.5      98.1       99.2
# 4   United States of America      90.9          70.3      95.4       99.9
# 5             United Kingdom      90.5          77.7      94.1       94.0
# 6             United Kingdom      88.2          77.2      93.9       95.1
# 7   United States of America      84.2          39.6      99.3       97.8
# 8             United Kingdom      89.2          90.0      94.5       88.3
# 9   United States of America      92.1          59.2      89.7       91.5
# 10  United States of America      83.0          48.1      92.9       93.2
# 11  United States of America      79.1          62.8      87.9       96.9
# 12  United States of America      80.9          58.5      89.2       92.3
# 13  United States of America      82.2          62.4      88.8       88.1
# 14               Switzerland      77.5          93.7      87.8       83.1
# 15  United States of America      83.9          53.3      89.1       84.1
# 16                    Canada      75.8             -      87.9       82.2
# 17  United States of America      73.8          90.9      73.8       92.6
# 18  United States of America      71.8          32.9      82.7       93.6
# 19  United States of America      70.3          39.1      79.3       95.7
#
#    income total_score  num_students  student_staff_ratio  \
# 0    34.5        96.1         20152                  8.9
# 1    83.7        96.0          2243                  6.9
# 2    87.5        95.6         11074                  9.0
# 3    64.3        94.3         15596                  7.8
# 4     NaN        94.2          7929                  8.4
# 5    57.0        91.2         18812                 11.8
# 6    73.5        91.2         19919                 11.6
# 7     NaN        91.1         36186                 16.4
# 8    92.9        90.6         15060                 11.7
# 9     NaN        89.5         11751                  4.4
# 10    NaN        87.7         38206                 10.3
# 11    NaN        86.9         14221                  6.9
# 12  100.0        86.4         15128                  3.6
# 13   34.7        83.9         21424                 10.2
# 14    NaN        83.4         18178                 14.7
# 15   59.6        83.4         41786                  9.0
# 16    NaN        82.0         66198                 19.5
# 17    NaN        81.0         25055                  5.9
# 18   43.7        79.5         20376                  6.5
# 19   53.7        79.3         11885                 13.1
#
#    international_students female_male_ratio  year
# 0                     25%               NaN  2011
# 1                     27%           33 : 67  2011
# 2                     33%           37 : 63  2011
# 3                     22%           42 : 58  2011
# 4                     27%           45 : 55  2011
# 5                     34%           46 : 54  2011
# 6                     34%           46 : 54  2011
# 7                     15%           50 : 50  2011
# 8                     51%           37 : 63  2011
# 9                     20%           50 : 50  2011
# 10                    15%           52 : 48  2011
# 11                    21%           42 : 58  2011
# 12                    23%           50 : 50  2011
# 13                    19%           48 : 52  2011
# 14                    37%           31 : 69  2011
# 15                    16%           48 : 52  2011
# 16                    15%               NaN  2011
# 17                    28%               NaN  2011
# 18                    20%           51 : 49  2011
# 19                    35%           39 : 61  2011

# %%
#Change data type of income from string to integer 
#df['A'] = np.floor(pd.to_numeric(df['A'], errors='coerce')).astype('Int64')
Times['income'] = np.floor(pd.to_numeric(Times['income'], errors='coerce')).astype('Int64')

# %%
#Check income variable via descriptive statistics 
Times.describe()
# Out:
#           teaching     research    citations      income   num_students  \
# count  2603.000000  2603.000000  2603.000000  2385.00000    2544.000000
# mean     37.801498    35.910257    60.921629    48.54130   23873.758648
# std      17.604218    21.254805    23.073219    21.19839   17675.946877
# min       9.900000     2.900000     1.200000    24.00000     462.000000
# 25%      24.700000    19.600000    45.500000    33.00000   12637.750000
# 50%      33.900000    30.500000    62.500000    41.00000   20851.000000
# 75%      46.400000    47.250000    79.050000    59.00000   29991.000000
# max      99.700000    99.400000   100.000000   100.00000  379231.000000
#
#        student_staff_ratio         year
# count          2544.000000  2603.000000
# mean             18.445283  2014.075682
# std              11.458698     1.685733
# min               0.600000  2011.000000
# 25%              11.975000  2013.000000
# 50%              16.100000  2014.000000
# 75%              21.500000  2016.000000
# max             162.600000  2016.000000

# %%
#Check data type of international variable 
Times['international'].dtype
# Out:
# dtype('O')

# %%
#Replace the "-" with "0" 
Times['international']=Times['international'].str.replace('-','NaN')
Times.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5432\1061634003.py in <module>
#       1 #Replace the "-" with "0"
# ----> 2 Times['international']=Times['international'].str.replace('-','NaN')
#       3 Times.head(20)
#
# NameError: name 'Times' is not defined

# %%
#Change data type of international from string to integer 
#df['A'] = np.floor(pd.to_numeric(df['A'], errors='coerce')).astype('Int64')
Times['international'] = np.floor(pd.to_numeric(Times['international'], errors='coerce')).astype('Int64')

# %%
#Check international variable in summary statistics 
Times.describe()
# Out:
#           teaching  international     research    citations      income  \
# count  2603.000000    2594.000000  2603.000000  2603.000000  2385.00000
# mean     37.801498      51.554356    35.910257    60.921629    48.54130
# std      17.604218      22.113535    21.254805    23.073219    21.19839
# min       9.900000       7.000000     2.900000     1.200000    24.00000
# 25%      24.700000      33.000000    19.600000    45.500000    33.00000
# 50%      33.900000      50.000000    30.500000    62.500000    41.00000
# 75%      46.400000      69.000000    47.250000    79.050000    59.00000
# max      99.700000     100.000000    99.400000   100.000000   100.00000
#
#         num_students  student_staff_ratio         year
# count    2544.000000          2544.000000  2603.000000
# mean    23873.758648            18.445283  2014.075682
# std     17675.946877            11.458698     1.685733
# min       462.000000             0.600000  2011.000000
# 25%     12637.750000            11.975000  2013.000000
# 50%     20851.000000            16.100000  2014.000000
# 75%     29991.000000            21.500000  2016.000000
# max    379231.000000           162.600000  2016.000000

# %%
#Check data type for total score 
Times['total_score'].dtype
# Out:
# dtype('O')

# %%
#Change data type of total score from string to integer 
Times['total_score'] = Times['total_score'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10964\1520003204.py in <module>
#       1 #Change data type of total score from string to integer
# ----> 2 Times['total_score'] = Times['total_score'].astype('float')
#
# C:\apps\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\apps\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# C:\apps\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# C:\apps\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# C:\apps\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# C:\apps\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# C:\apps\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1179     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1180         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1181         return arr.astype(dtype, copy=True)
#    1182
#    1183     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
#Replace the "-" with "NaN" 
Times['total_score']=Times['total_score'].str.replace('-','NaN')

# %%
#Change data type of total score from string to integer 
#df['A'] = np.floor(pd.to_numeric(df['A'], errors='coerce')).astype('Int64')
Times['total_score'] = np.floor(pd.to_numeric(Times['total_score'], errors='coerce')).astype('Int64')

# %%
#Check total score via summary statistics 
Times.describe()
# Out:
#           teaching  international     research    citations      income  \
# count  2603.000000    2594.000000  2603.000000  2603.000000  2385.00000
# mean     37.801498      51.554356    35.910257    60.921629    48.54130
# std      17.604218      22.113535    21.254805    23.073219    21.19839
# min       9.900000       7.000000     2.900000     1.200000    24.00000
# 25%      24.700000      33.000000    19.600000    45.500000    33.00000
# 50%      33.900000      50.000000    30.500000    62.500000    41.00000
# 75%      46.400000      69.000000    47.250000    79.050000    59.00000
# max      99.700000     100.000000    99.400000   100.000000   100.00000
#
#        total_score   num_students  student_staff_ratio         year
# count  1201.000000    2544.000000          2544.000000  2603.000000
# mean     59.406328   23873.758648            18.445283  2014.075682
# std      12.804482   17675.946877            11.458698     1.685733
# min      41.000000     462.000000             0.600000  2011.000000
# 25%      50.000000   12637.750000            11.975000  2013.000000
# 50%      56.000000   20851.000000            16.100000  2014.000000
# 75%      66.000000   29991.000000            21.500000  2016.000000
# max      96.000000  379231.000000           162.600000  2016.000000

# %%
#Check international students data type 
Times['international_students'].dtype
# Out:
# dtype('O')

# %%
#Drop/strip the % sign from the internation students column 
#df['returns'] = (df['returns'].str.strip('%').astype(int))
#df['returns'] = df['returns'].str.replace('\%','')
Times['international_students'] = Times['international_students'].str.replace('\%', '')
# Out:
# C:\Users\ctede\AppData\Local\Temp\ipykernel_10964\779022720.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   Times['international_students'] = Times['international_students'].str.replace('\%', '')

# %%
Times.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching  international  research  citations  income  total_score  \
# 0      99.7             72      98.7       98.8      34           96
# 1      97.7             54      98.0       99.9      83           96
# 2      97.8             82      91.4       99.9      87           95
# 3      98.3             29      98.1       99.2      64           94
# 4      90.9             70      95.4       99.9    <NA>           94
#
#    num_students  student_staff_ratio international_students female_male_ratio  \
# 0         20152                  8.9                     25               NaN
# 1          2243                  6.9                     27           33 : 67
# 2         11074                  9.0                     33           37 : 63
# 3         15596                  7.8                     22           42 : 58
# 4          7929                  8.4                     27           45 : 55
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
#Change data type of international_students from string to integer 
Times['international_students'] = Times['international_students'].astype('float').astype('Int64')

# %%
Times.describe()
# Out:
#           teaching  international     research    citations      income  \
# count  2603.000000    2594.000000  2603.000000  2603.000000  2385.00000
# mean     37.801498      51.554356    35.910257    60.921629    48.54130
# std      17.604218      22.113535    21.254805    23.073219    21.19839
# min       9.900000       7.000000     2.900000     1.200000    24.00000
# 25%      24.700000      33.000000    19.600000    45.500000    33.00000
# 50%      33.900000      50.000000    30.500000    62.500000    41.00000
# 75%      46.400000      69.000000    47.250000    79.050000    59.00000
# max      99.700000     100.000000    99.400000   100.000000   100.00000
#
#        total_score   num_students  student_staff_ratio  \
# count  1201.000000    2544.000000          2544.000000
# mean     59.406328   23873.758648            18.445283
# std      12.804482   17675.946877            11.458698
# min      41.000000     462.000000             0.600000
# 25%      50.000000   12637.750000            11.975000
# 50%      56.000000   20851.000000            16.100000
# 75%      66.000000   29991.000000            21.500000
# max      96.000000  379231.000000           162.600000
#
#        international_students         year
# count             2536.000000  2603.000000
# mean                15.444006  2014.075682
# std                 10.591464     1.685733
# min                  0.000000  2011.000000
# 25%                  8.000000  2013.000000
# 50%                 13.000000  2014.000000
# 75%                 21.000000  2016.000000
# max                 82.000000  2016.000000

# %% [markdown]
# # Export Times data set
# ### Will finish cleaning at a later date

# %%
#Clean Times data frame 
Times.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Times_clean.pkl'))
