# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#Import clean data sets 
path = r'C:\Users\ctede\OneDrive\Desktop\World University Rankings Analysis'
#CWUR = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'CWUR_clean.pkl'))
ARWU = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ARWU_merged.pkl'))
#Times = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Times_clean.pkl'))

# %%
ARWU.head()
# Out:
#   world_rank     university_name national_rank  total_score  alumni  award  \
# 0          1  Harvard University             1        100.0   100.0  100.0
# 1          1  Harvard University             1        100.0   100.0  100.0
# 2          1  Harvard University             1        100.0   100.0  100.0
# 3          1  Harvard University             1        100.0   100.0  100.0
# 4          1  Harvard University             1        100.0   100.0  100.0
#
#     hici     ns    pub   pcp  year        country         region  \
# 0  100.0  100.0  100.0  72.4  2005  United States  North America
# 1  100.0  100.0  100.0  73.6  2006  United States  North America
# 2  100.0  100.0  100.0  73.0  2007  United States  North America
# 3  100.0  100.0  100.0  74.1  2008  United States  North America
# 4  100.0  100.0  100.0  74.8  2009  United States  North America
#
#   Score Category
# 0        Over 65
# 1        Over 65
# 2        Over 65
# 3        Over 65
# 4        Over 65

# %%
ARWU.dtypes
# Out:
# world_rank          object
# university_name     object
# national_rank       object
# total_score        float64
# alumni             float64
# award              float64
# hici               float64
# ns                 float64
# pub                float64
# pcp                float64
# year                 int64
# country             object
# region              object
# Score Category      object
# dtype: object

# %%
ARWU.isnull().sum()
# Out:
# world_rank            0
# university_name       0
# national_rank         0
# total_score        2299
# alumni                0
# award                 1
# hici                  1
# ns                   12
# pub                   1
# pcp                   1
# year                  0
# country               0
# region                0
# Score Category     2299
# dtype: int64

# %%
ARWU.shape
# Out:
# (3014, 14)

# %%
ARWU_filter = ARWU[ARWU['world_rank'].str.contains('-')]

# %%
ARWU_filter
# Out:
#      world_rank                      university_name national_rank  \
# 447     101-150              University of Rochester         52-65
# 467     101-150      Case Western Reserve University         53-64
# 468     101-150      Case Western Reserve University         52-65
# 498     101-150                    Tohoku University           5-7
# 499     101-150                    Tohoku University           4-6
# ...         ...                                  ...           ...
# 3009    401-500           Capital Medical University         28-32
# 3010    401-500  Queensland University of Technology            20
# 3011    401-500      Sharif University of Technology             2
# 3012    401-500                  University of Genoa         11-20
# 3013    401-500                University of Seville          9-13
#
#       total_score  alumni  award  hici    ns   pub   pcp  year        country  \
# 447           NaN    24.6    7.7  25.2  20.8  39.0  20.8  2015  United States
# ...

# %% [markdown]
# Do all rows that have a null/missing total score, also have a world rank with a dash "-"?

# %%
ARWU_filter.isnull().head(100)
# Out:
#      world_rank  university_name  national_rank  total_score  alumni  award  \
# 447       False            False          False         True   False  False
# 467       False            False          False         True   False  False
# 468       False            False          False         True   False  False
# 498       False            False          False         True   False  False
# 499       False            False          False         True   False  False
# ..          ...              ...            ...          ...     ...    ...
# 759       False            False          False         True   False  False
# 760       False            False          False         True   False  False
# 761       False            False          False         True   False  False
# 762       False            False          False         True   False  False
# 763       False            False          False         True   False  False
#
# ...

# %% [markdown]
# Most likely, yes. The number of missing values for the total score is 2299, for the score category is 2299, and for the world ranks that are not well-defined 2299.

# %%
#remove the missing rows
#df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]
#df_prods_clean
ARWU_no_nulls = ARWU[ARWU['total_score'].isnull() == False]
ARWU_no_nulls
# Out:
#      world_rank           university_name national_rank  total_score  alumni  \
# 0             1        Harvard University             1        100.0   100.0
# 1             1        Harvard University             1        100.0   100.0
# 2             1        Harvard University             1        100.0   100.0
# 3             1        Harvard University             1        100.0   100.0
# 4             1        Harvard University             1        100.0   100.0
# ...         ...                       ...           ...          ...     ...
# 2947         93  Arizona State University            47         24.5     0.0
# 2948         96                 KU Leuven             2         24.2     0.0
# 2949         90                 KU Leuven             2         24.7     0.0
# 3003         16  Johns Hopkins University            14         46.3    37.7
# 3004        100      Texas A&M University            51         23.9     0.0
#
# ...

# %%
#Check filter again 
ARWU_filter_2 = ARWU_no_nulls[ARWU_no_nulls['world_rank'].str.contains('-')]
ARWU_filter_2
# Out:
# Empty DataFrame
# Columns: [world_rank, university_name, national_rank, total_score, alumni, award, hici, ns, pub, pcp, year, country, region, Score Category]
# Index: []

# %% [markdown]
# # Export ARWU without nulls

# %%
#Export the CLEAN products dataframe 
ARWU_no_nulls.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ARWU_no_nulls.pkl'))
