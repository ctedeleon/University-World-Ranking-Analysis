# %% [markdown]
# # Import libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# # Import data set

# %%
path = r'C:\Users\ctede\OneDrive\Desktop\World University Rankings Analysis'
merged = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'merged_datasets_outer_2.csv'))
CWUR = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'CWUR_new_cols.pkl'))
ARWU = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ARWU_rename_countries.pkl'))
times = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Times_new_cols.pkl'))

# %% [markdown]
# # EDA

# %%
merged.shape
# Out:
# (6045, 24)

# %%
#Count the number of unique university names
merged[['university name','region']].groupby('region').nunique()
# Out:
#                university name
# region
# Africa                      16
# Asia                       338
# Europe                     498
# North America              314
# Oceania                     44
# South America               43

# %%
#Count the number of countries 
merged['country'].value_counts()
# Out:
# United States of America    1558
# United Kingdom               513
# Japan                        377
# China                        316
# Germany                      312
#                             ...
# Nigeria                        1
# Ghana                          1
# Bangladesh                     1
# Belarus                        1
# Luxembourg                     1
# Name: country, Length: 77, dtype: int64

# %%
merged.head()
# Out:
#    Unnamed: 0                        university name  \
# 0           0                     Harvard University
# 1           1     California Institute of Technology
# 2           2  Massachusetts Institute of Technology
# 3           3                    Stanford University
# 4           4                   Princeton University
#
#                     country  times research  times score         region  \
# 0  United States of America            98.7        98.70  North America
# 1  United States of America            98.0        97.70  North America
# 2  United States of America            91.4        91.40  North America
# 3  United States of America            98.1        98.10  North America
# 4  United States of America            95.4        93.15  North America
#
#    times teaching  year  times international  times num students  ...  \
# 0            99.7  2011                 72.0             20152.0  ...
# ...

# %%
CWUR.head()
# Out:
#    world_rank                        university_name         country  \
# 0           1                     Harvard University   United States
# 1           2  Massachusetts Institute of Technology   United States
# 2           3                    Stanford University   United States
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology   United States
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  patents   score  year         region  \
# ...

# %%
merged['university name'].nunique() #number of distinct university names for the merged dataset
# Out:
# 1253

# %%
CWUR['university_name'].nunique() #number of distinct university names for the CWUR dataset
# Out:
# 1024

# %%
CWUR.shape
# Out:
# (2200, 15)

# %%
ARWU['university_name'].nunique() #number of distinct university names for the ARWU dataset
# Out:
# 384

# %%
times['university_name'].nunique() #number of distinct university names for the times dataset
# Out:
# 818

# %%
times.shape
# Out:
# (2603, 17)

# %%
#sub dataframe for CWUR only
columns = ["university name", "CWUR score"]

# %%
sub = merged[columns]

# %%
sub['university name'].nunique()
# Out:
# 1253

# %%
dups = merged.duplicated()
dups.shape
# Out:
# (6045,)

# %%
merged[merged['university name']=='Harvard University']
# Out:
#       Unnamed: 0     university name                   country  \
# 0              0  Harvard University  United States of America
# 201          201  Harvard University  United States of America
# 605          605  Harvard University  United States of America
# 1003        1003  Harvard University  United States of America
# 1403        1403  Harvard University  United States of America
# 1808        1808  Harvard University  United States of America
# 2603        2603  Harvard University  United States of America
# 2604        2604  Harvard University  United States of America
# 2605        2605  Harvard University  United States of America
# 2606        2606  Harvard University  United States of America
# 2607        2607  Harvard University  United States of America
# 2608        2608  Harvard University  United States of America
#
#       times research  times score         region  times teaching  year  \
# 0               98.7         98.7  North America            99.7  2011
# ...

# %%
ARWU[ARWU['university_name']=='Harvard University']
# Out:
#    world_rank     university_name national_rank  total_score  alumni  award  \
# 0           1  Harvard University             1        100.0   100.0  100.0
# 1           1  Harvard University             1        100.0   100.0  100.0
# 2           1  Harvard University             1        100.0   100.0  100.0
# 3           1  Harvard University             1        100.0   100.0  100.0
# 4           1  Harvard University             1        100.0   100.0  100.0
# 5           1  Harvard University             1        100.0   100.0  100.0
# 6           1  Harvard University             1        100.0   100.0  100.0
# 7           1  Harvard University             1        100.0   100.0  100.0
# 8           1  Harvard University           1.0        100.0   100.0  100.0
# 9           1  Harvard University             1        100.0   100.0  100.0
# 10          1  Harvard University             1        100.0   100.0  100.0
#
# ...

# %%
merged[merged['university name']=='Stanford University']
# Out:
#       Unnamed: 0      university name                   country  \
# 3              3  Stanford University  United States of America
# 202          202  Stanford University  United States of America
# 603          603  Stanford University  United States of America
# 1005        1005  Stanford University  United States of America
# 1405        1405  Stanford University  United States of America
# 1805        1805  Stanford University  United States of America
# 2615        2615  Stanford University  United States of America
# 2616        2616  Stanford University  United States of America
# 2617        2617  Stanford University  United States of America
# 2618        2618  Stanford University  United States of America
# 2619        2619  Stanford University  United States of America
# 2620        2620  Stanford University  United States of America
#
#       times research  times score         region  times teaching  year  \
# ...

# %%
merged[merged['country']=='United States of America']
# Out:
#       Unnamed: 0                        university name  \
# 0              0                     Harvard University
# 1              1     California Institute of Technology
# 2              2  Massachusetts Institute of Technology
# 3              3                    Stanford University
# 4              4                   Princeton University
# ...          ...                                    ...
# 5950        5950     University of Southern Mississippi
# 5955        5955                     Oakland University
# 5962        5962             University of North Dakota
# 5977        5977         University of Texas at El Paso
# 5984        5984       University of California, Merced
#
#                        country  times research  times score         region  \
# 0     United States of America            98.7        98.70  North America
# 1     United States of America            98.0        97.70  North America
# ...

# %%
#Count the number of countries CWUR 
CWUR['country'].nunique()
# Out:
# 59

# %%
#Count the number of countries ARWU 
ARWU['country'].nunique()
# Out:
# 42

# %%
#Count the number of countries Times
times['country'].nunique()
# Out:
# 70

# %%
#Count the number of countries merged 
merged['country'].nunique()
# Out:
# 77
